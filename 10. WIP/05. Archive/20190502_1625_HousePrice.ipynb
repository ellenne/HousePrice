# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns
import numpy as np
import scipy.stats as stats
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn.utils import check_array
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
# Definitions
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# %matplotlib inline

# %%
train_url = 'https://raw.githubusercontent.com/ellenne/rawdata/master/train.csv'
test_url = 'https://raw.githubusercontent.com/ellenne/rawdata/master/test.csv'

# %%
df_train = pd.read_csv(train_url)
df_test = pd.read_csv(test_url)

# %% [markdown]
# Here we separate our variables into numeric and categorical. We also take out the `Id` and `SalePrice` will be set as output variable

# %%
all_vars = list(df_train)
output_var = 'SalePrice'
num_vars = list(df_train._get_numeric_data())
cat_vars = list(set(all_vars) - set(num_vars))
num_vars = list(set(num_vars) - set(['SalePrice', 'Id']))
(output_var, num_vars, cat_vars)
# Out:
# ('SalePrice',
#  ['BsmtFullBath',
#   'YearRemodAdd',
#   'BedroomAbvGr',
#   '3SsnPorch',
#   'MSSubClass',
#   'LotArea',
#   'YearBuilt',
#   'BsmtFinSF2',
#   'TotalBsmtSF',
#   'OverallCond',
#   'MasVnrArea',
#   'LowQualFinSF',
#   'GarageArea',
#   'KitchenAbvGr',
#   'ScreenPorch',
#   'WoodDeckSF',
#   'BsmtHalfBath',
#   'OpenPorchSF',
#   'BsmtFinSF1',
#   '2ndFlrSF',
#   'MoSold',
#   'FullBath',
#   'TotRmsAbvGrd',
#   'HalfBath',
#   'BsmtUnfSF',
#   'GrLivArea',
#   'GarageYrBlt',
#   'MiscVal',
#   'YrSold',
#   'LotFrontage',
#   'PoolArea',
#   'OverallQual',
#   'EnclosedPorch',
#   'GarageCars',
#   'Fireplaces',
#   '1stFlrSF'],
#  ['Exterior1st',
#   'RoofStyle',
#   'Heating',
#   'Neighborhood',
#   'BsmtCond',
#   'MasVnrType',
#   'HeatingQC',
#   'PavedDrive',
#   'SaleType',
#   'LandContour',
#   'LotShape',
#   'Exterior2nd',
#   'Alley',
#   'MSZoning',
#   'FireplaceQu',
#   'Utilities',
#   'MiscFeature',
#   'PoolQC',
#   'LandSlope',
#   'GarageType',
#   'BsmtFinType1',
#   'RoofMatl',
#   'HouseStyle',
#   'Fence',
#   'CentralAir',
#   'BsmtQual',
#   'Condition2',
#   'Street',
#   'BldgType',
#   'Condition1',
#   'GarageFinish',
#   'ExterQual',
#   'BsmtFinType2',
#   'BsmtExposure',
#   'LotConfig',
#   'KitchenQual',
#   'ExterCond',
#   'GarageQual',
#   'Electrical',
#   'Foundation',
#   'SaleCondition',
#   'GarageCond',
#   'Functional'])

# %%
## for the categorical variables if there is a missing value the category MISSING is created and filled
for c in cat_vars:
    df_train[c] = df_train[c].astype('category')
    if df_train[c].isnull().any():        
        df_train[c] = df_train[c].cat.add_categories(['MISSING'])
        df_train[c] = df_train[c].fillna('MISSING')

# %%
## same for test set
for c in cat_vars:
    df_test[c] = df_test[c].astype('category')
    if df_test[c].isnull().any():        
        df_test[c] = df_test[c].cat.add_categories(['MISSING'])
        df_test[c] = df_test[c].fillna('MISSING')

# %%
# function to encode the categorical variables
def encode(frame, feature):
    list_1 = pd.DataFrame()
    # level for each variable
    list_1['level'] = frame[feature].unique()
    # since we will make use of dictionaries, having the index will make the index the key (!!)
    list_1.index = list_1.level
    # connected mean of sales price for the current level
    list_1['spmean'] = frame[[feature, output_var]].groupby(feature).mean()[output_var]
    # then we have to order
    list_1 = list_1.sort_values('spmean')
    # then we can create the value that we want to assign - from 1 to rows list_1+1 (note we cannot use len because)
    # list_1 is a dataframe and not a list
    values = []
    j = 1
    for i in range(0, len(list_1)):
        if list_1['level'][i].upper() in ['MISSING', 'NONE', 'NA', 'N']:
            values.append(0)
        else:
            values.append(j)
            j += 1
            
    list_1['value'] = values
    # now let's make use of dictionaries that are so wonderful for cases like these
    list_1 = list_1['value'].to_dict()    
    for cat, o in list_1.items():
        frame.loc[frame[feature] == cat, feature+'_E'] = o

cat_vars_Enc = []
for q in cat_vars:
    encode(df_train, q)    
    cat_vars_Enc.append(q+"_E")

cat_vars_Enc
# Out:
# ['Exterior1st_E',
#  'RoofStyle_E',
#  'Heating_E',
#  'Neighborhood_E',
#  'BsmtCond_E',
#  'MasVnrType_E',
#  'HeatingQC_E',
#  'PavedDrive_E',
#  'SaleType_E',
#  'LandContour_E',
#  'LotShape_E',
#  'Exterior2nd_E',
#  'Alley_E',
#  'MSZoning_E',
#  'FireplaceQu_E',
#  'Utilities_E',
#  'MiscFeature_E',
#  'PoolQC_E',
#  'LandSlope_E',
#  'GarageType_E',
#  'BsmtFinType1_E',
#  'RoofMatl_E',
#  'HouseStyle_E',
#  'Fence_E',
#  'CentralAir_E',
#  'BsmtQual_E',
#  'Condition2_E',
#  'Street_E',
#  'BldgType_E',
#  'Condition1_E',
#  'GarageFinish_E',
#  'ExterQual_E',
#  'BsmtFinType2_E',
#  'BsmtExposure_E',
#  'LotConfig_E',
#  'KitchenQual_E',
#  'ExterCond_E',
#  'GarageQual_E',
#  'Electrical_E',
#  'Foundation_E',
#  'SaleCondition_E',
#  'GarageCond_E',
#  'Functional_E']

# %%
# this method copies the encode of encodedFrame in frame. The underlying hypothesis is that the encoded frame contains
# the raw variable and the encoded one that has the same name + '_E', so the method builds the dictionary level, value
# and apply it to the frame. It fails if the frame contains values not present in the encodedFrame
def copyEncode(encodedFrame, frame, feature):    
    list_1 = pd.DataFrame()
    # level for each variable
    list_1['level'] = encodedFrame[feature].unique()    
    levels = encodedFrame[feature].unique()    
    # build the values
    values = []
    for lev in levels:
        values.append(min(encodedFrame[feature + '_E'].loc[encodedFrame[feature] == lev]))
    list_1['value'] = values
    
    # now let's make use of dictionaries that are so wonderful for cases like these
    list_1d = {}
    for val in values:
        list_1d[list_1['level'][values.index(val)]] = val
    # a missing element can be present in the test set but not in the training set
    list_1d['MISSING'] = 0
    list_1 = list_1d        
    for cat, o in list_1.items():
        frame.loc[frame[feature] == cat, feature+'_E'] = o
        
for q in cat_vars:
    copyEncode(df_train, df_test, q)    
    print(q+"_E")
# Out:
# Exterior1st_E
# RoofStyle_E
# Heating_E
# Neighborhood_E
# BsmtCond_E
# MasVnrType_E
# HeatingQC_E
# PavedDrive_E
# SaleType_E
# LandContour_E
# LotShape_E
# Exterior2nd_E
# Alley_E
# MSZoning_E
# FireplaceQu_E
# Utilities_E
# MiscFeature_E
# PoolQC_E
# LandSlope_E
# GarageType_E
# BsmtFinType1_E
# RoofMatl_E
# HouseStyle_E
# Fence_E
# CentralAir_E
# BsmtQual_E
# Condition2_E
# Street_E
# BldgType_E
# Condition1_E
# GarageFinish_E
# ExterQual_E
# BsmtFinType2_E
# BsmtExposure_E
# LotConfig_E
# KitchenQual_E
# ExterCond_E
# GarageQual_E
# Electrical_E
# Foundation_E
# SaleCondition_E
# GarageCond_E
# Functional_E

# %%
df_train.shape, df_train.shape
# Out:
# ((1460, 124), (1460, 124))

# %%
len(cat_vars) + len(cat_vars_Enc) + len(num_vars)
# Out:
# 122

# %% [markdown]
# Let's define our KPI - Root Mean Squared Logaritmic Error. In the rank tihs is used as KPI to evaluate the model.  <br/>
#
#
# This function will be used to evaluate the goodness of the model.

# %%
## RMSLE - Root Mean Squared Logaritmic Error
## https://www.kaggle.com/marknagelberg/rmsle-function
## This is the parameter used to rank models
def rmsle(y_pred, y_test) : 
    assert len(y_test) == len(y_pred)
    return np.sqrt(np.mean((np.log(1+y_pred) - np.log(1+y_test))**2))

# %% [markdown]
# Now we will begin our feature engineering. We will add new features, simplify some and transform others so that we will have a wider range of features between which we can choose those that best fit our model.

# %%
## variable simplification - I put S after the variable name

df_train["SimplOverallQual_S"] = df_train['OverallQual'].replace(
    {1 : 1, 2 : 1, 3 : 1,        # bad
     4 : 2, 5 : 2, 6 : 2,        # average
     7 : 3, 8 : 3, 9 : 3, 10 : 3 # good
    })

df_train["SimplOverallCond_S"] = df_train['OverallCond'].replace(
    {1 : 1, 2 : 1, 3 : 1, # bad
     4 : 2, 5 : 2, 6 : 2, # average
     7 : 3, 8 : 3, 9 : 3, 10 : 3 # good
    })

df_train["SimplPoolQC_S"] = df_train['PoolQC_E'].replace(
    {1 : 1, 2 : 1, # average
     3 : 2, 4 : 2  # good
    })

df_train["SimplGarageCond_S"] = df_train['GarageCond_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
     })

df_train["SimplGarageQual_S"] = df_train['GarageQual_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

df_train["SimplFireplaceQu_S"] = df_train['FireplaceQu_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

df_train["SimplFunctional_S"] = df_train['Functional_E'].replace(
    {1 : 1, 2 : 1, # bad
     3 : 2, 4 : 2, # major
     5 : 3, 6 : 3, 7 : 3, # minor
     8 : 4 # typical
    })

df_train["SimplKitchenQual_S"] = df_train['KitchenQual_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

df_train["SimplHeatingQC_S"] = df_train['HeatingQC_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

df_train["SimplBsmtFinType1_S"] = df_train['BsmtFinType1_E'].replace(
    {1 : 1, # unfinished
     2 : 1, 3 : 1, # rec room
     4 : 2, 5 : 2, 6 : 2 # living quarters
    })

df_train["SimplBsmtFinType2_S"] = df_train['BsmtFinType2_E'].replace(
    {1 : 1, # unfinished
     2 : 1, 3 : 1, # rec room
     4 : 2, 5 : 2, 6 : 2 # living quarters
    })

df_train["SimplBsmtCond_S"] = df_train['BsmtCond_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

df_train["SimplBsmtQual_S"] = df_train['BsmtQual_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

df_train["SimplExterCond_S"] = df_train['ExterCond_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

df_train["SimplExterQual_S"] = df_train['ExterQual_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

# House completed before sale or not
df_train["BoughtOffPlan_S"] = df_train['SaleCondition'].replace(
    {"Abnorml" : 0, "Alloca" : 0, "AdjLand" : 0,
     "Family" : 0, "Normal" : 0, "Partial" : 1})

# Has masonry veneer or not
df_train["HasMasVnr_S"] = df_train['MasVnrType'].replace(
    {"BrkCmn" : 1, "BrkFace" : 1, "CBlock" : 1, "Stone" : 1, "None" : 0, "MISSING": 0})

# %%
## variable simplification in the training

df_test["SimplOverallQual_S"] = df_test['OverallQual'].replace(
    {1 : 1, 2 : 1, 3 : 1,        # bad
     4 : 2, 5 : 2, 6 : 2,        # average
     7 : 3, 8 : 3, 9 : 3, 10 : 3 # good
    })

df_test["SimplOverallCond_S"] = df_test['OverallCond'].replace(
    {1 : 1, 2 : 1, 3 : 1, # bad
     4 : 2, 5 : 2, 6 : 2, # average
     7 : 3, 8 : 3, 9 : 3, 10 : 3 # good
    })

df_test["SimplPoolQC_S"] = df_test['PoolQC_E'].replace(
    {1 : 1, 2 : 1, # average
     3 : 2, 4 : 2  # good
    })

df_test["SimplGarageCond_S"] = df_test['GarageCond_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
     })

df_test["SimplGarageQual_S"] = df_test['GarageQual_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

df_test["SimplFireplaceQu_S"] = df_test['FireplaceQu_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

df_test["SimplFunctional_S"] = df_test['Functional_E'].replace(
    {1 : 1, 2 : 1, # bad
     3 : 2, 4 : 2, # major
     5 : 3, 6 : 3, 7 : 3, # minor
     8 : 4 # typical
    })

df_test["SimplKitchenQual_S"] = df_test['KitchenQual_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

df_test["SimplHeatingQC_S"] = df_test['HeatingQC_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

df_test["SimplBsmtFinType1_S"] = df_test['BsmtFinType1_E'].replace(
    {1 : 1, # unfinished
     2 : 1, 3 : 1, # rec room
     4 : 2, 5 : 2, 6 : 2 # living quarters
    })

df_test["SimplBsmtFinType2_S"] = df_test['BsmtFinType2_E'].replace(
    {1 : 1, # unfinished
     2 : 1, 3 : 1, # rec room
     4 : 2, 5 : 2, 6 : 2 # living quarters
    })

df_test["SimplBsmtCond_S"] = df_test['BsmtCond_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

df_test["SimplBsmtQual_S"] = df_test['BsmtQual_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

df_test["SimplExterCond_S"] = df_test['ExterCond_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

df_test["SimplExterQual_S"] = df_test['ExterQual_E'].replace(
    {1 : 1, # bad
     2 : 1, 3 : 1, # average
     4 : 2, 5 : 2 # good
    })

# House completed before sale or not
df_test["BoughtOffPlan_S"] = df_test['SaleCondition'].replace(
    {"Abnorml" : 0, "Alloca" : 0, "AdjLand" : 0,
     "Family" : 0, "Normal" : 0, "Partial" : 1})

# Has masonry veneer or not
df_test["HasMasVnr_S"] = df_test['MasVnrType'].replace(
    {"BrkCmn" : 1, "BrkFace" : 1, "CBlock" : 1, "Stone" : 1, "None" : 0, "MISSING": 0})

# %%
cat_vars_S = ['SimplOverallQual_S', 'SimplOverallCond_S', 'SimplPoolQC_S', 
              'SimplGarageCond_S', 'SimplGarageQual_S', 'SimplFireplaceQu_S', 
              'SimplFunctional_S', 'SimplKitchenQual_S', 'SimplHeatingQC_S', 
              'SimplBsmtFinType1_S', 'SimplBsmtFinType2_S', 'SimplBsmtCond_S', 
              'SimplBsmtQual_S', 'SimplExterCond_S', 'SimplExterQual_S', 
              'BoughtOffPlan_S', 'HasMasVnr_S']

# %%
df_train["OverallGrade_D"] = df_train["OverallQual"].astype(np.float64) * \
                              df_train["OverallCond"].astype(np.float64)

# Overall quality of the garage
df_train["GarageGrade_D"] = df_train["GarageQual_E"].astype(np.float64) * \
                            df_train["GarageCond_E"].astype(np.float64)

# Overall quality of the exterior
df_train["ExterGrade_D"] = df_train["ExterQual_E"].astype(np.float64) * \
                          df_train["ExterCond_E"].astype(np.float64)

# Overall kitchen score
df_train["KitchenScore_D"] = df_train["KitchenAbvGr"].astype(np.float64) * \
                            df_train["KitchenQual_E"].astype(np.float64)

# Overall fireplace score
df_train["FireplaceScore_D"] = df_train["Fireplaces"].astype(np.float64) * \
                              df_train["FireplaceQu_E"].astype(np.float64)

# Overall garage score
df_train["GarageScore_D"] = df_train["GarageArea"].astype(np.float64) * \
                            df_train["GarageQual_E"].astype(np.float64)

# Overall pool score
df_train["PoolScore_D"] = df_train["PoolArea"].astype(np.float64) * \
                          df_train["PoolQC_E"].astype(np.float64)

# Simplified overall quality of the house
df_train["SimplOverallGrade_D"] = df_train["SimplOverallQual_S"].astype(np.float64) * \
                               df_train["SimplOverallCond_S"].astype(np.float64)

# Simplified overall pool score
df_train["SimplPoolScore_D"] = df_train["PoolArea"].astype(np.float64) * \
                                df_train["SimplPoolQC_S"].astype(np.float64)

# Simplified overall garage score
df_train["SimplGarageScore_D"] = df_train["GarageArea"].astype(np.float64) * \
                                df_train["SimplGarageQual_S"].astype(np.float64)

# Simplified overall fireplace score
df_train["SimplFireplaceScore_D"] = df_train["Fireplaces"].astype(np.float64) *\
                              df_train["SimplFireplaceQu_S"].astype(np.float64)

# Simplified overall kitchen score
df_train["SimplKitchenScore_D"] = df_train["KitchenAbvGr"].astype(np.float64) * \
                              df_train["SimplKitchenQual_S"].astype(np.float64)

# Total number of bathrooms
df_train["TotalBath_D"] = df_train["BsmtFullBath"] + \
                        (0.5 * df_train["BsmtHalfBath"]) + df_train["FullBath"] +\
                        (0.5 * df_train["HalfBath"])

# Total SF for house (incl. basement)
df_train["AllSF_D"] = df_train["GrLivArea"] + df_train["TotalBsmtSF"]

# Total SF for 1st + 2nd floors
df_train["AllFlrsSF_D"] = df_train["1stFlrSF"] + df_train["2ndFlrSF"]

# Total SF for porch
df_train["AllPorchSF_D"] = df_train["OpenPorchSF"] + df_train["EnclosedPorch"] + \
                          df_train["3SsnPorch"] + df_train["ScreenPorch"]

# Simplified overall quality of the exterior
df_train["SimplExterGrade_D"] = df_train["SimplExterQual_S"].astype(np.float64) * \
                            df_train["SimplExterCond_S"].astype(np.float64)

# %%
# variable transformation in test set

# Overall quality of the house
df_test["OverallGrade_D"] = df_test["OverallQual"].astype(np.float64) * \
                            df_test["OverallCond"].astype(np.float64)

# Overall quality of the garage
df_test["GarageGrade_D"] = df_test["GarageQual_E"].astype(np.float64) * \
                            df_test["GarageCond_E"].astype(np.float64)

# Overall quality of the exterior
df_test["ExterGrade_D"] = df_test["ExterQual_E"].astype(np.float64) * \
                          df_test["ExterCond_E"].astype(np.float64)

# Overall kitchen score
df_test["KitchenScore_D"] = df_test["KitchenAbvGr"].astype(np.float64) * \
                            df_test["KitchenQual_E"].astype(np.float64)

# Overall fireplace score
df_test["FireplaceScore_D"] = df_test["Fireplaces"].astype(np.float64) * \
                              df_test["FireplaceQu_E"].astype(np.float64)

# Overall garage score
df_test["GarageScore_D"] = df_test["GarageArea"].astype(np.float64) * \
                            df_test["GarageQual_E"].astype(np.float64)

# Overall pool score
df_test["PoolScore_D"] = df_test["PoolArea"].astype(np.float64) * \
                          df_test["PoolQC_E"].astype(np.float64)

# Simplified overall quality of the house
df_test["SimplOverallGrade_D"] = df_test["SimplOverallQual_S"].astype(np.float64) * \
                              df_test["SimplOverallCond_S"].astype(np.float64)

# Simplified overall pool score
df_test["SimplPoolScore_D"] = df_test["PoolArea"].astype(np.float64) * \
                              df_test["SimplPoolQC_S"].astype(np.float64)

# Simplified overall garage score
df_test["SimplGarageScore_D"] = df_test["GarageArea"].astype(np.float64) * \
                                df_test["SimplGarageQual_S"].astype(np.float64)

# Simplified overall fireplace score
df_test["SimplFireplaceScore_D"] = df_test["Fireplaces"].astype(np.float64) * \
                                df_test["SimplFireplaceQu_S"].astype(np.float64)

# Simplified overall kitchen score
df_test["SimplKitchenScore_D"] = df_test["KitchenAbvGr"].astype(np.float64) * \
                                df_test["SimplKitchenQual_S"].astype(np.float64)

# Total number of bathrooms
df_test["TotalBath_D"] = df_test["BsmtFullBath"] + \
                        (0.5 * df_test["BsmtHalfBath"]) + \
                          df_test["FullBath"] + \
                        (0.5 * df_test["HalfBath"])

# Total SF for house (incl. basement)
df_test["AllSF_D"] = df_test["GrLivArea"] + df_test["TotalBsmtSF"]

# Total SF for 1st + 2nd floors
df_test["AllFlrsSF_D"] = df_test["1stFlrSF"] + df_test["2ndFlrSF"]

# Total SF for porch
df_test["AllPorchSF_D"] = df_test["OpenPorchSF"] + df_test["EnclosedPorch"] + \
                          df_test["3SsnPorch"] + df_test["ScreenPorch"]

# Simplified overall quality of the exterior
df_test["SimplExterGrade_D"] = df_test["SimplExterQual_S"].astype(np.float64) * \
                                df_test["SimplExterCond_S"].astype(np.float64)

# %%
cat_vars_D = ['OverallGrade_D', 'GarageGrade_D', 'ExterGrade_D', 'KitchenScore_D', 
              'FireplaceScore_D', 'GarageScore_D', 'PoolScore_D', 'SimplOverallGrade_D', 
              'SimplPoolScore_D', 'SimplGarageScore_D', 'SimplFireplaceScore_D', 
              'SimplKitchenScore_D', 'TotalBath_D', 'AllSF_D', 'AllFlrsSF_D', 
              'AllPorchSF_D', 'SimplExterGrade_D']

# %%
# Create new features
# 3* Polynomials on the top 10 existing features
df_train["OverallQual_TL2"] = np.log10(df_train["OverallQual"] ** 2 + 1)
df_train["OverallQual_TL3"] = np.log10(df_train["OverallQual"] ** 3 + 1)
df_train["OverallQual_TSQ"] = np.sqrt(df_train["OverallQual"])
df_train["OverallQual_TLOG"] = np.log10(df_train["OverallQual"] + 1)

df_train["AllSF_TL2"] = np.log10(df_train["AllSF_D"] ** 2 + 1)
df_train["AllSF_TL3"] = np.log10(df_train["AllSF_D"] ** 3 + 1)
df_train["AllSF_TSQ"] = np.sqrt(df_train["AllSF_D"])
df_train["AllSF_TLOG"] = np.log10(df_train["AllSF_D"] + 1)

df_train["AllFlrsSF_TL2"] = np.log10(df_train["AllFlrsSF_D"] ** 2 + 1)
df_train["AllFlrsSF_TL3"] = np.log10(df_train["AllFlrsSF_D"] ** 3 + 1)
df_train["AllFlrsSF_TSQ"] = np.sqrt(df_train["AllFlrsSF_D"])
df_train["AllFlrsSF_TLOG"] = np.log10(df_train["AllFlrsSF_D"] + 1)

df_train["GrLivArea_TL2"] = np.log10(df_train["GrLivArea"] ** 2 + 1)
df_train["GrLivArea_TL3"] = np.log10(df_train["GrLivArea"] ** 3 + 1)
df_train["GrLivArea_TSQ"] = np.sqrt(df_train["GrLivArea"])
df_train["GrLivArea_TLOG"] = np.log10(df_train["GrLivArea"] + 1)

df_train["SimplOverallQual_TL2"] = np.log10(df_train["SimplOverallQual_S"] ** 2 + 1)
df_train["SimplOverallQual_TL3"] = np.log10(df_train["SimplOverallQual_S"] ** 3 + 1)
df_train["SimplOverallQual_TSQ"] = np.sqrt(df_train["SimplOverallQual_S"])
df_train["SimplOverallQual_TLOG"] = np.log10(df_train["SimplOverallQual_S"] + 1)

df_train["ExterQual_TL2"] = np.log10(df_train["ExterQual_E"] ** 2 + 1)
df_train["ExterQual_TL3"] = np.log10(df_train["ExterQual_E"] ** 3 + 1)
df_train["ExterQual_TSQ"] = np.sqrt(df_train["ExterQual_E"])
df_train["ExterQual_TLOG"] = np.log10(df_train["ExterQual_E"] + 1) 

df_train["GarageCars_TL2"] = np.log10(df_train["GarageCars"] ** 2 + 1)
df_train["GarageCars_TL3"] = np.log10(df_train["GarageCars"] ** 3 + 1)
df_train["GarageCars_TSQ"] = np.sqrt(df_train["GarageCars"])
df_train["GarageCars_TLOG"] = np.log10(df_train["GarageCars"] + 1)

df_train["TotalBath_TL2"] = np.log10(df_train["TotalBath_D"] ** 2 + 1)
df_train["TotalBath_TL3"] = np.log10(df_train["TotalBath_D"] ** 3 + 1)
df_train["TotalBath_TSQ"] = np.sqrt(df_train["TotalBath_D"])
df_train["TotalBath_TLOG"] = np.log10(df_train["TotalBath_D"] + 1)

df_train["KitchenQual_TL2"] = np.log10(df_train["KitchenQual_E"] ** 2 + 1)
df_train["KitchenQual_TL3"] = np.log10(df_train["KitchenQual_E"] ** 3 + 1)
df_train["KitchenQual_TSQ"] = np.sqrt(df_train["KitchenQual_E"])
df_train["KitchenQual_TLOG"] = np.log10(df_train["KitchenQual_E"] + 1)

df_train["GarageScore_TL2"] = np.log10(df_train["GarageScore_D"] ** 2 + 1)
df_train["GarageScore_TL3"] = np.log10(df_train["GarageScore_D"] ** 3 + 1)
df_train["GarageScore_TSQ"] = np.sqrt(df_train["GarageScore_D"])
df_train["GarageScore_TLOG"] = np.log10(df_train["GarageScore_D"] + 1)

# %%
# transformation for test set
df_test["OverallQual_TL2"] = np.log10(df_test["OverallQual"] ** 2 + 1)
df_test["OverallQual_TL3"] = np.log10(df_test["OverallQual"] ** 3 + 1)
df_test["OverallQual_TSQ"] = np.sqrt(df_test["OverallQual"])
df_test["OverallQual_TLOG"] = np.log10(df_test["OverallQual"] + 1)

df_test["AllSF_TL2"] = np.log10(df_test["AllSF_D"] ** 2 + 1)
df_test["AllSF_TL3"] = np.log10(df_test["AllSF_D"] ** 3 + 1)
df_test["AllSF_TSQ"] = np.sqrt(df_test["AllSF_D"])
df_test["AllSF_TLOG"] = np.log10(df_test["AllSF_D"] + 1)

df_test["AllFlrsSF_TL2"] = np.log10(df_test["AllFlrsSF_D"] ** 2 + 1)
df_test["AllFlrsSF_TL3"] = np.log10(df_test["AllFlrsSF_D"] ** 3 + 1)
df_test["AllFlrsSF_TSQ"] = np.sqrt(df_test["AllFlrsSF_D"])
df_test["AllFlrsSF_TLOG"] = np.log10(df_test["AllFlrsSF_D"] + 1)

df_test["GrLivArea_TL2"] = np.log10(df_test["GrLivArea"] ** 2 + 1)
df_test["GrLivArea_TL3"] = np.log10(df_test["GrLivArea"] ** 3 + 1)
df_test["GrLivArea_TSQ"] = np.sqrt(df_test["GrLivArea"])
df_test["GrLivArea_TLOG"] = np.log10(df_test["GrLivArea"] + 1)

df_test["SimplOverallQual_TL2"] = np.log10(df_test["SimplOverallQual_S"] ** 2 + 1)
df_test["SimplOverallQual_TL3"] = np.log10(df_test["SimplOverallQual_S"] ** 3 + 1)
df_test["SimplOverallQual_TSQ"] = np.sqrt(df_test["SimplOverallQual_S"])
df_test["SimplOverallQual_TLOG"] = np.log10(df_test["SimplOverallQual_S"] + 1)

df_test["ExterQual_TL2"] = np.log10(df_test["ExterQual_E"] ** 2 + 1)
df_test["ExterQual_TL3"] = np.log10(df_test["ExterQual_E"] ** 3 + 1)
df_test["ExterQual_TSQ"] = np.sqrt(df_test["ExterQual_E"])
df_test["ExterQual_TLOG"] = np.log10(df_test["ExterQual_E"] + 1) 

df_test["GarageCars_TL2"] = np.log10(df_test["GarageCars"] ** 2 + 1)
df_test["GarageCars_TL3"] = np.log10(df_test["GarageCars"] ** 3 + 1)
df_test["GarageCars_TSQ"] = np.sqrt(df_test["GarageCars"])
df_test["GarageCars_TLOG"] = np.log10(df_test["GarageCars"] + 1)

df_test["TotalBath_TL2"] = np.log10(df_test["TotalBath_D"] ** 2 + 1)
df_test["TotalBath_TL3"] = np.log10(df_test["TotalBath_D"] ** 3 + 1)
df_test["TotalBath_TSQ"] = np.sqrt(df_test["TotalBath_D"])
df_test["TotalBath_TLOG"] = np.log10(df_test["TotalBath_D"] + 1)

df_test["KitchenQual_TL2"] = np.log10(df_test["KitchenQual_E"] ** 2 + 1)
df_test["KitchenQual_TL3"] = np.log10(df_test["KitchenQual_E"] ** 3 + 1)
df_test["KitchenQual_TSQ"] = np.sqrt(df_test["KitchenQual_E"])
df_test["KitchenQual_TLOG"] = np.log10(df_test["KitchenQual_E"] + 1)

df_test["GarageScore_TL2"] = np.log10(df_test["GarageScore_D"] ** 2 + 1)
df_test["GarageScore_TL3"] = np.log10(df_test["GarageScore_D"] ** 3 + 1)
df_test["GarageScore_TSQ"] = np.sqrt(df_test["GarageScore_D"])
df_test["GarageScore_TLOG"] = np.log10(df_test["GarageScore_D"] + 1)

# %%
cat_vars_T = ['OverallQual_TL2', 'OverallQual_TL3', 'OverallQual_TSQ', 'OverallQual_TLOG',
              'AllSF_TL2', 'AllSF_TL3', 'AllSF_TSQ', 'AllSF_TLOG', 'AllFlrsSF_TL2', 
              'AllFlrsSF_TL3', 'AllFlrsSF_TSQ', 'AllFlrsSF_TLOG', 'GrLivArea_TL2', 
              'GrLivArea_TL3', 'GrLivArea_TSQ', 'GrLivArea_TLOG', 'SimplOverallQual_TL2',
              'SimplOverallQual_TL3', 'SimplOverallQual_TSQ', 'SimplOverallQual_TLOG', 
              'ExterQual_TL2', 'ExterQual_TL3', 'ExterQual_TSQ', 'ExterQual_TLOG', 
              'GarageCars_TL2', 'GarageCars_TL3', 'GarageCars_TSQ', 'GarageCars_TLOG', 
              'TotalBath_TL2', 'TotalBath_TL3', 'TotalBath_TSQ', 'TotalBath_TLOG', 
              'KitchenQual_TL2', 'KitchenQual_TL3', 'KitchenQual_TSQ', 'KitchenQual_TLOG',
              'GarageScore_TL2', 'GarageScore_TL3', 'GarageScore_TSQ', 'GarageScore_TLOG']

# %%
len(num_vars) + len(cat_vars_Enc) + len(cat_vars_D) + len(cat_vars_S) + len(cat_vars_T)
# Out:
# 153

# %%
all_vars = num_vars + cat_vars_Enc + cat_vars_D + cat_vars_S + cat_vars_T
len(all_vars)
# Out:
# 153

# %%
# remove the variables containing NA from the dataframe
vars_with_na = df_train.columns[df_train.isnull().any()]
all_vars = list(set(all_vars) - set(vars_with_na))
len(all_vars)
# Out:
# 150

# %%
output_var
# Out:
# 'SalePrice'

# %%
# clearly in df_test the sales price is missing and this is the variable that the submission wants to forecast
df_train.shape, df_test.shape
# Out:
# ((1460, 198), (1459, 197))

# %%
df_train['SalePrice_TLOG'] = np.log10(df_train[[output_var]] + 1)

# %% [markdown]
# <ol>
#    <li> Split in Training and Test set (p=0.2)
#    <li>Initialise the RMSLE to +inf
#    <li> Iterate again to add more variables 3.1. Iterate over the 154 variables in the following way:
#      <ol>
#        <li> For i = 1 To 10:
#          <ol>
#            <li> Determine Training and Test set
#            <li> Build the model with the i-th variable on the Training set
#            <li> Forecast on the Test set and calculate predicted
#            <li> Calculate the RMSLE comparing predicted Y on Test and real Y on Test
#          </ol>
#          <li>Calculate KPI i-th as the MEDIAN of RMSLE over the 10 validations
#          <li> If Current KPI > KPI i-th then update Current KPI and include the variable
#      </ol>
#      <li> Stop after N iterations if you fail to add a variable
# </ol>

# %% [markdown]
# Since I want to use the formula, I define the variable basket where I put a `v_` to all variables.

# %%
new_vars=[]
all_vars_rn = []

# %%
vars = df_train.columns

new_vars = []
for a in vars:
    new_vars.append('v_' + a)
df_train.columns = new_vars
all_vars_rn = []
for a in all_vars:
    all_vars_rn.append('v_' + a)
new_vars
# Out:
# ['v_Id',
#  'v_MSSubClass',
#  'v_MSZoning',
#  'v_LotFrontage',
#  'v_LotArea',
#  'v_Street',
#  'v_Alley',
#  'v_LotShape',
#  'v_LandContour',
#  'v_Utilities',
#  'v_LotConfig',
#  'v_LandSlope',
#  'v_Neighborhood',
#  'v_Condition1',
#  'v_Condition2',
#  'v_BldgType',
#  'v_HouseStyle',
#  'v_OverallQual',
#  'v_OverallCond',
#  'v_YearBuilt',
#  'v_YearRemodAdd',
#  'v_RoofStyle',
#  'v_RoofMatl',
#  'v_Exterior1st',
#  'v_Exterior2nd',
#  'v_MasVnrType',
#  'v_MasVnrArea',
#  'v_ExterQual',
#  'v_ExterCond',
#  'v_Foundation',
#  'v_BsmtQual',
#  'v_BsmtCond',
#  'v_BsmtExposure',
#  'v_BsmtFinType1',
#  'v_BsmtFinSF1',
#  'v_BsmtFinType2',
#  'v_BsmtFinSF2',
#  'v_BsmtUnfSF',
#  'v_TotalBsmtSF',
#  'v_Heating',
#  'v_HeatingQC',
#  'v_CentralAir',
#  'v_Electrical',
#  'v_1stFlrSF',
#  'v_2ndFlrSF',
#  'v_LowQualFinSF',
#  'v_GrLivArea',
#  'v_BsmtFullBath',
#  'v_BsmtHalfBath',
#  'v_FullBath',
#  'v_HalfBath',
#  'v_BedroomAbvGr',
#  'v_KitchenAbvGr',
#  'v_KitchenQual',
#  'v_TotRmsAbvGrd',
#  'v_Functional',
#  'v_Fireplaces',
#  'v_FireplaceQu',
#  'v_GarageType',
#  'v_GarageYrBlt',
#  'v_GarageFinish',
#  'v_GarageCars',
#  'v_GarageArea',
#  'v_GarageQual',
#  'v_GarageCond',
#  'v_PavedDrive',
#  'v_WoodDeckSF',
#  'v_OpenPorchSF',
#  'v_EnclosedPorch',
#  'v_3SsnPorch',
#  'v_ScreenPorch',
#  'v_PoolArea',
#  'v_PoolQC',
#  'v_Fence',
#  'v_MiscFeature',
#  'v_MiscVal',
#  'v_MoSold',
#  'v_YrSold',
#  'v_SaleType',
#  'v_SaleCondition',
#  'v_SalePrice',
#  'v_Exterior1st_E',
#  'v_RoofStyle_E',
#  'v_Heating_E',
#  'v_Neighborhood_E',
#  'v_BsmtCond_E',
#  'v_MasVnrType_E',
#  'v_HeatingQC_E',
#  'v_PavedDrive_E',
#  'v_SaleType_E',
#  'v_LandContour_E',
#  'v_LotShape_E',
#  'v_Exterior2nd_E',
#  'v_Alley_E',
#  'v_MSZoning_E',
#  'v_FireplaceQu_E',
#  'v_Utilities_E',
#  'v_MiscFeature_E',
#  'v_PoolQC_E',
#  'v_LandSlope_E',
#  'v_GarageType_E',
#  'v_BsmtFinType1_E',
#  'v_RoofMatl_E',
#  'v_HouseStyle_E',
#  'v_Fence_E',
#  'v_CentralAir_E',
#  'v_BsmtQual_E',
#  'v_Condition2_E',
#  'v_Street_E',
#  'v_BldgType_E',
#  'v_Condition1_E',
#  'v_GarageFinish_E',
#  'v_ExterQual_E',
#  'v_BsmtFinType2_E',
#  'v_BsmtExposure_E',
#  'v_LotConfig_E',
#  'v_KitchenQual_E',
#  'v_ExterCond_E',
#  'v_GarageQual_E',
#  'v_Electrical_E',
#  'v_Foundation_E',
#  'v_SaleCondition_E',
#  'v_GarageCond_E',
#  'v_Functional_E',
#  'v_SimplOverallQual_S',
#  'v_SimplOverallCond_S',
#  'v_SimplPoolQC_S',
#  'v_SimplGarageCond_S',
#  'v_SimplGarageQual_S',
#  'v_SimplFireplaceQu_S',
#  'v_SimplFunctional_S',
#  'v_SimplKitchenQual_S',
#  'v_SimplHeatingQC_S',
#  'v_SimplBsmtFinType1_S',
#  'v_SimplBsmtFinType2_S',
#  'v_SimplBsmtCond_S',
#  'v_SimplBsmtQual_S',
#  'v_SimplExterCond_S',
#  'v_SimplExterQual_S',
#  'v_BoughtOffPlan_S',
#  'v_HasMasVnr_S',
#  'v_OverallGrade_D',
#  'v_GarageGrade_D',
#  'v_ExterGrade_D',
#  'v_KitchenScore_D',
#  'v_FireplaceScore_D',
#  'v_GarageScore_D',
#  'v_PoolScore_D',
#  'v_SimplOverallGrade_D',
#  'v_SimplPoolScore_D',
#  'v_SimplGarageScore_D',
#  'v_SimplFireplaceScore_D',
#  'v_SimplKitchenScore_D',
#  'v_TotalBath_D',
#  'v_AllSF_D',
#  'v_AllFlrsSF_D',
#  'v_AllPorchSF_D',
#  'v_SimplExterGrade_D',
#  'v_OverallQual_TL2',
#  'v_OverallQual_TL3',
#  'v_OverallQual_TSQ',
#  'v_OverallQual_TLOG',
#  'v_AllSF_TL2',
#  'v_AllSF_TL3',
#  'v_AllSF_TSQ',
#  'v_AllSF_TLOG',
#  'v_AllFlrsSF_TL2',
#  'v_AllFlrsSF_TL3',
#  'v_AllFlrsSF_TSQ',
#  'v_AllFlrsSF_TLOG',
#  'v_GrLivArea_TL2',
#  'v_GrLivArea_TL3',
#  'v_GrLivArea_TSQ',
#  'v_GrLivArea_TLOG',
#  'v_SimplOverallQual_TL2',
#  'v_SimplOverallQual_TL3',
#  'v_SimplOverallQual_TSQ',
#  'v_SimplOverallQual_TLOG',
#  'v_ExterQual_TL2',
#  'v_ExterQual_TL3',
#  'v_ExterQual_TSQ',
#  'v_ExterQual_TLOG',
#  'v_GarageCars_TL2',
#  'v_GarageCars_TL3',
#  'v_GarageCars_TSQ',
#  'v_GarageCars_TLOG',
#  'v_TotalBath_TL2',
#  'v_TotalBath_TL3',
#  'v_TotalBath_TSQ',
#  'v_TotalBath_TLOG',
#  'v_KitchenQual_TL2',
#  'v_KitchenQual_TL3',
#  'v_KitchenQual_TSQ',
#  'v_KitchenQual_TLOG',
#  'v_GarageScore_TL2',
#  'v_GarageScore_TL3',
#  'v_GarageScore_TSQ',
#  'v_GarageScore_TLOG',
#  'v_SalePrice_TLOG']

# %% [markdown]
# Now I simulate one iteration and then I need to automate the procedure

# %%
X = df_train[all_vars_rn]
yL = df_train[['v_SalePrice_TLOG','v_SalePrice']]
X_train, X_test, y_train, y_test = train_test_split(df_train[all_vars_rn], yL, test_size=0.2)

# %%
X.shape, X_train.shape, yL.shape, y_train.shape, X_test.shape
# Out:
# ((1460, 150), (1168, 150), (1460, 2), (1168, 2), (292, 150))

# %%
all_vars_rn[0]
# Out:
# 'v_Alley_E'

# %%
import statsmodels.formula.api as smf
df_training = pd.DataFrame()
df_training = X_train
df_training['v_SalePrice_TLOG'] = y_train['v_SalePrice_TLOG']
df_testing = pd.DataFrame()
df_testing = X_test
df_testing['v_SalePrice_TLOG'] = y_test['v_SalePrice_TLOG']
model = smf.ols(formula = 'v_SalePrice_TLOG ~ ' + all_vars_rn[0], data = df_training)
fitted = model.fit()
print (fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       v_SalePrice_TLOG   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     12.25
# Date:                Thu, 02 May 2019   Prob (F-statistic):           0.000483
# Time:                        09:47:39   Log-Likelihood:                 390.62
# No. Observations:                1168   AIC:                            -777.2
# Df Residuals:                    1166   BIC:                            -767.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.2241      0.005   1000.454      0.000       5.214       5.234
# v_Alley_E     -0.0479      0.014     -3.500      0.000      -0.075      -0.021
# ==============================================================================
# Omnibus:                       16.858   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.019
# Skew:                           0.013   Prob(JB):                     4.99e-07
# Kurtosis:                       3.772   Cond. No.                         2.72
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# checking the performance of the current variable
y_NewLog = fitted.predict(df_testing)
y_New = y_NewLog.apply(lambda x: 10 ** x)
tpl = (all_vars_rn[0],rmsle(y_New, y_test['v_SalePrice']))
tpl
# Out:
# ('v_Alley_E', 0.3933937769918365)

# %%
# setting for the iteration
rs = 123 #random_state
perf_iter = []
perf_KPI = [] 
form_base = 'v_SalePrice_TLOG ~ '
best_perf = 1000
deleted_vars = []
k = 0

while k < 150 or best_perf > 0.05 or len(all_vars_rn) > 0:
  
  if len(all_vars_rn) == 0:
    break
  
  perf_iter = []
  perf_var = []
  cur_perf = 0
  
  for cur_var in all_vars_rn:
    if k == 0:
      form = form_base + cur_var # formula
    else:
      # here we completed at least one full scan
      form = form_base + ' + ' + cur_var
      
    perf_iter = []
    # in order to make the procedure not dependent from the data we do a sort of
    # cross validation changing test and train set each time

    for cross in range(10):
      # Step 1: change the train and test set
      X_train, X_test, y_train, y_test = train_test_split(df_train, 
                                                          yL, 
                                                          test_size=0.2,
                                                          random_state = rs)
      # Step 2: fit the model
      df_training = pd.DataFrame()
      df_training = X_train
      df_training['v_SalePrice_TLOG'] = y_train['v_SalePrice_TLOG']
      df_testing = pd.DataFrame()
      df_testing = X_test
      df_testing['v_SalePrice_TLOG'] = y_test['v_SalePrice_TLOG']
      model_tmp = smf.ols(formula = form, data = df_training)
      fitted_tmp = model_tmp.fit()

      # Step 3: calculate the performance
      y_NewLog_tmp = fitted_tmp.predict(df_testing)
      y_New_tmp = y_NewLog_tmp.apply(lambda x: 10 ** x)
      tpl = (cur_var, rmsle(y_New_tmp, y_test['v_SalePrice']))
      perf_iter.append(tpl)
      rs += 1


    # at the end we need to take the median of the RMSLE that we obtain sorting the
    # list by the second element and we take the average between element 4 and 5
    perf_iter = sorted(perf_iter, key=lambda x: x[1])
    perf_iter_tpl = (cur_var, (perf_iter[4][1] + perf_iter[5][1]) / 2 )
    # at the end we have the variable name and the median of the RMSLE 
    perf_var.append(perf_iter_tpl)

  perf_var = sorted(perf_var, key=lambda x: x[1])
  chosen_var = perf_var[0][0]
  cur_perf = perf_var[0][1]
  if k == 0:
    perf_KPI.append(cur_perf)  
    print('Chosen variable {}: {} - perf: {}'.format(k, chosen_var, perf_KPI[k]))
    form_base += chosen_var
    best_perf = cur_perf
    
  else:
    if best_perf > cur_perf:
      # so there is an improvement      
      perf_KPI.append(cur_perf)
      best_perf = cur_perf
      print('Chosen variable {}: {} - perf: {}'.format(k, chosen_var, cur_perf))
      form_base += ' + ' + chosen_var
      # if there is an improvement I will add again all the variables that I took out
      # because with another predictor these variables can work
      if len(deleted_vars) > 0:
        all_vars_rn += deleted_vars
        deleted_vars = []
    else:        
      print('Chosen variable {}: {} - perf: {} - not an improvement deleted'.format(k, chosen_var, cur_perf))      
      k -= 1
      deleted_vars.append(chosen_var)
  
  print('Equation: {}'.format(form_base))  
  all_vars_rn.remove(chosen_var)  
  print("Variables left: {} - best performance: {}".format(len(all_vars_rn), best_perf))
  k+=1
# Out:
# Chosen variable 0: v_OverallQual_TSQ - perf: 0.2279355456748226
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ
# Variables left: 149 - best performance: 0.2279355456748226
# Chosen variable 1: v_AllSF_TSQ - perf: 0.1768248191201061
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ
# Variables left: 148 - best performance: 0.1768248191201061
# Chosen variable 2: v_Neighborhood_E - perf: 0.16169796287164562
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E
# Variables left: 147 - best performance: 0.16169796287164562
# Chosen variable 3: v_TotalBath_TLOG - perf: 0.15089648239366332
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG
# Variables left: 146 - best performance: 0.15089648239366332
# Chosen variable 4: v_SimplOverallGrade_D - perf: 0.14502126256004766
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D
# Variables left: 145 - best performance: 0.14502126256004766
# Chosen variable 5: v_GarageCars - perf: 0.13865894315092997
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars
# Variables left: 144 - best performance: 0.13865894315092997
# Chosen variable 6: v_WoodDeckSF - perf: 0.1394470235898887 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars
# Variables left: 143 - best performance: 0.13865894315092997
# Chosen variable 6: v_GarageScore_TL3 - perf: 0.13758010825060046
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3
# Variables left: 143 - best performance: 0.13758010825060046
# Chosen variable 7: v_GarageScore_TLOG - perf: 0.13324032178645207
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 142 - best performance: 0.13324032178645207
# Chosen variable 8: v_PoolQC_E - perf: 0.13843969789035665 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 141 - best performance: 0.13324032178645207
# Chosen variable 8: v_YearRemodAdd - perf: 0.13781401165161844 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 140 - best performance: 0.13324032178645207
# Chosen variable 8: v_MSSubClass - perf: 0.13641028626619278 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 139 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplFireplaceQu_S - perf: 0.13554695068403616 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 138 - best performance: 0.13324032178645207
# Chosen variable 8: v_LandSlope_E - perf: 0.13467831659101862 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 137 - best performance: 0.13324032178645207
# Chosen variable 8: v_ExterCond_E - perf: 0.1392861620247769 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 136 - best performance: 0.13324032178645207
# Chosen variable 8: v_GrLivArea_TL3 - perf: 0.1375764997402505 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 135 - best performance: 0.13324032178645207
# Chosen variable 8: v_ExterQual_E - perf: 0.13784902310021263 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 134 - best performance: 0.13324032178645207
# Chosen variable 8: v_AllFlrsSF_TL3 - perf: 0.1358514346100339 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 133 - best performance: 0.13324032178645207
# Chosen variable 8: v_WoodDeckSF - perf: 0.13879445498916038 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 132 - best performance: 0.13324032178645207
# Chosen variable 8: v_MSZoning_E - perf: 0.1359855467369342 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 131 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplBsmtQual_S - perf: 0.13663447392485026 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 130 - best performance: 0.13324032178645207
# Chosen variable 8: v_TotalBath_TSQ - perf: 0.13656853396786228 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 129 - best performance: 0.13324032178645207
# Chosen variable 8: v_KitchenQual_TL2 - perf: 0.13643970906834968 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 128 - best performance: 0.13324032178645207
# Chosen variable 8: v_KitchenQual_E - perf: 0.13769637999217033 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 127 - best performance: 0.13324032178645207
# Chosen variable 8: v_BoughtOffPlan_S - perf: 0.13878493416370632 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 126 - best performance: 0.13324032178645207
# Chosen variable 8: v_BldgType_E - perf: 0.13694466011606132 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 125 - best performance: 0.13324032178645207
# Chosen variable 8: v_KitchenAbvGr - perf: 0.1342641790561381 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 124 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplKitchenQual_S - perf: 0.1355973315635285 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 123 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplOverallQual_TLOG - perf: 0.134450120375998 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 122 - best performance: 0.13324032178645207
# Chosen variable 8: v_OverallQual_TLOG - perf: 0.13919325533840748 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 121 - best performance: 0.13324032178645207
# Chosen variable 8: v_EnclosedPorch - perf: 0.13615087432790657 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 120 - best performance: 0.13324032178645207
# Chosen variable 8: v_GarageCars_TSQ - perf: 0.13555685447312377 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 119 - best performance: 0.13324032178645207
# Chosen variable 8: v_AllSF_TL2 - perf: 0.13656921808446565 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 118 - best performance: 0.13324032178645207
# Chosen variable 8: v_BsmtUnfSF - perf: 0.13498071560677155 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 117 - best performance: 0.13324032178645207
# Chosen variable 8: v_GrLivArea_TSQ - perf: 0.13704579084071755 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 116 - best performance: 0.13324032178645207
# Chosen variable 8: v_ExterGrade_D - perf: 0.13384106823884892 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 115 - best performance: 0.13324032178645207
# Chosen variable 8: v_LotShape_E - perf: 0.13796693823972206 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 114 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplOverallCond_S - perf: 0.13869867436469746 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 113 - best performance: 0.13324032178645207
# Chosen variable 8: v_1stFlrSF - perf: 0.1367646071989404 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 112 - best performance: 0.13324032178645207
# Chosen variable 8: v_GrLivArea_TLOG - perf: 0.14041864581745234 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 111 - best performance: 0.13324032178645207
# Chosen variable 8: v_LotArea - perf: 0.1373400974957483 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 110 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplFireplaceScore_D - perf: 0.13780956900934538 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 109 - best performance: 0.13324032178645207
# Chosen variable 8: v_ScreenPorch - perf: 0.1378282100652039 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 108 - best performance: 0.13324032178645207
# Chosen variable 8: v_OverallGrade_D - perf: 0.13580909303617428 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 107 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplBsmtFinType1_S - perf: 0.13996184923381774 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 106 - best performance: 0.13324032178645207
# Chosen variable 8: v_LandContour_E - perf: 0.1384779013544395 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 105 - best performance: 0.13324032178645207
# Chosen variable 8: v_SaleType_E - perf: 0.13564897925997543 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 104 - best performance: 0.13324032178645207
# Chosen variable 8: v_AllPorchSF_D - perf: 0.1385472824456605 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 103 - best performance: 0.13324032178645207
# Chosen variable 8: v_ExterQual_TL3 - perf: 0.1394245078345822 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 102 - best performance: 0.13324032178645207
# Chosen variable 8: v_GarageCars_TLOG - perf: 0.13831069609373733 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 101 - best performance: 0.13324032178645207
# Chosen variable 8: v_PavedDrive_E - perf: 0.13644132046755808 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 100 - best performance: 0.13324032178645207
# Chosen variable 8: v_FireplaceScore_D - perf: 0.13800944402641618 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 99 - best performance: 0.13324032178645207
# Chosen variable 8: v_BsmtExposure_E - perf: 0.1373214072629553 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 98 - best performance: 0.13324032178645207
# Chosen variable 8: v_MoSold - perf: 0.14009790958610624 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 97 - best performance: 0.13324032178645207
# Chosen variable 8: v_ExterQual_TSQ - perf: 0.1381099380160975 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 96 - best performance: 0.13324032178645207
# Chosen variable 8: v_Alley_E - perf: 0.1390107653958405 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 95 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplOverallQual_TL3 - perf: 0.13764327824124675 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 94 - best performance: 0.13324032178645207
# Chosen variable 8: v_GarageScore_TSQ - perf: 0.13726507606748273 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 93 - best performance: 0.13324032178645207
# Chosen variable 8: v_HalfBath - perf: 0.13770969709977426 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 92 - best performance: 0.13324032178645207
# Chosen variable 8: v_Exterior1st_E - perf: 0.13716429006292874 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 91 - best performance: 0.13324032178645207
# Chosen variable 8: v_ExterQual_TL2 - perf: 0.1381344221884102 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 90 - best performance: 0.13324032178645207
# Chosen variable 8: v_OverallCond - perf: 0.1355096351220888 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 89 - best performance: 0.13324032178645207
# Chosen variable 8: v_CentralAir_E - perf: 0.13483543848618273 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 88 - best performance: 0.13324032178645207
# Chosen variable 8: v_Utilities_E - perf: 0.13943655275835737 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 87 - best performance: 0.13324032178645207
# Chosen variable 8: v_RoofStyle_E - perf: 0.13879160898800708 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 86 - best performance: 0.13324032178645207
# Chosen variable 8: v_3SsnPorch - perf: 0.13802392498957816 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 85 - best performance: 0.13324032178645207
# Chosen variable 8: v_OverallQual_TL3 - perf: 0.1388956072786231 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 84 - best performance: 0.13324032178645207
# Chosen variable 8: v_GarageQual_E - perf: 0.13598567170591203 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 83 - best performance: 0.13324032178645207
# Chosen variable 8: v_GarageArea - perf: 0.13840397874293764 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 82 - best performance: 0.13324032178645207
# Chosen variable 8: v_Fireplaces - perf: 0.13862768693917515 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 81 - best performance: 0.13324032178645207
# Chosen variable 8: v_KitchenQual_TLOG - perf: 0.13549365116798462 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 80 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplFunctional_S - perf: 0.1409691105601348 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 79 - best performance: 0.13324032178645207
# Chosen variable 8: v_GarageCars_TL2 - perf: 0.1349180290241342 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 78 - best performance: 0.13324032178645207
# Chosen variable 8: v_FireplaceQu_E - perf: 0.13742476985810786 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 77 - best performance: 0.13324032178645207
# Chosen variable 8: v_Exterior2nd_E - perf: 0.13693139609371935 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 76 - best performance: 0.13324032178645207
# Chosen variable 8: v_HeatingQC_E - perf: 0.1388566365053258 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 75 - best performance: 0.13324032178645207
# Chosen variable 8: v_BsmtFinType1_E - perf: 0.13947891792645734 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 74 - best performance: 0.13324032178645207
# Chosen variable 8: v_SaleCondition_E - perf: 0.13901756024986506 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 73 - best performance: 0.13324032178645207
# Chosen variable 8: v_AllFlrsSF_D - perf: 0.13952922599769485 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 72 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplOverallQual_TSQ - perf: 0.13918714283944839 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 71 - best performance: 0.13324032178645207
# Chosen variable 8: v_Functional_E - perf: 0.14077464334717277 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 70 - best performance: 0.13324032178645207
# Chosen variable 8: v_HasMasVnr_S - perf: 0.13696445844103447 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 69 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplGarageQual_S - perf: 0.13990771222677592 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 68 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplExterQual_S - perf: 0.1365417998913726 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 67 - best performance: 0.13324032178645207
# Chosen variable 8: v_ExterQual_TLOG - perf: 0.13813399654375652 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 66 - best performance: 0.13324032178645207
# Chosen variable 8: v_GarageFinish_E - perf: 0.13874807174067066 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 65 - best performance: 0.13324032178645207
# Chosen variable 8: v_YearBuilt - perf: 0.13795707551962183 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 64 - best performance: 0.13324032178645207
# Chosen variable 8: v_BsmtCond_E - perf: 0.1386915178699758 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 63 - best performance: 0.13324032178645207
# Chosen variable 8: v_GarageScore_D - perf: 0.13851082453199554 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 62 - best performance: 0.13324032178645207
# Chosen variable 8: v_YrSold - perf: 0.13754324091960646 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 61 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplGarageCond_S - perf: 0.1389177825975655 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 60 - best performance: 0.13324032178645207
# Chosen variable 8: v_FullBath - perf: 0.1383060950505486 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 59 - best performance: 0.13324032178645207
# Chosen variable 8: v_Heating_E - perf: 0.13539805785625605 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 58 - best performance: 0.13324032178645207
# Chosen variable 8: v_BsmtFinSF1 - perf: 0.13888047914794271 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 57 - best performance: 0.13324032178645207
# Chosen variable 8: v_KitchenQual_TSQ - perf: 0.14057790176367974 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 56 - best performance: 0.13324032178645207
# Chosen variable 8: v_Condition1_E - perf: 0.14248235933379605 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 55 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplGarageScore_D - perf: 0.1401017244498417 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 54 - best performance: 0.13324032178645207
# Chosen variable 8: v_2ndFlrSF - perf: 0.13695952474902778 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 53 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplBsmtCond_S - perf: 0.13737565703428284 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 52 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplBsmtFinType2_S - perf: 0.13974074423386817 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 51 - best performance: 0.13324032178645207
# Chosen variable 8: v_LotConfig_E - perf: 0.13514450090088734 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 50 - best performance: 0.13324032178645207
# Chosen variable 8: v_KitchenQual_TL3 - perf: 0.13845435468513229 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 49 - best performance: 0.13324032178645207
# Chosen variable 8: v_PoolArea - perf: 0.1390291733685171 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 48 - best performance: 0.13324032178645207
# Chosen variable 8: v_TotRmsAbvGrd - perf: 0.13889352123595922 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 47 - best performance: 0.13324032178645207
# Chosen variable 8: v_AllSF_TLOG - perf: 0.14056700875021663 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 46 - best performance: 0.13324032178645207
# Chosen variable 8: v_GarageCond_E - perf: 0.13826253692903723 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 45 - best performance: 0.13324032178645207
# Chosen variable 8: v_AllSF_TL3 - perf: 0.13931273947360906 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 44 - best performance: 0.13324032178645207
# Chosen variable 8: v_SimplExterGrade_D - perf: 0.1400437079101332 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG
# Variables left: 43 - best performance: 0.13324032178645207
# Chosen variable 8: v_MiscFeature_E - perf: 0.13196003352908717
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 141 - best performance: 0.13196003352908717
# Chosen variable 9: v_MSZoning_E - perf: 0.1369263049438343 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 140 - best performance: 0.13196003352908717
# Chosen variable 9: v_FireplaceQu_E - perf: 0.13463875388448313 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 139 - best performance: 0.13196003352908717
# Chosen variable 9: v_KitchenQual_E - perf: 0.13490699071790305 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 138 - best performance: 0.13196003352908717
# Chosen variable 9: v_SimplKitchenQual_S - perf: 0.1377833994123539 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 137 - best performance: 0.13196003352908717
# Chosen variable 9: v_GarageScore_D - perf: 0.1357732747339198 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 136 - best performance: 0.13196003352908717
# Chosen variable 9: v_CentralAir_E - perf: 0.1345418865633805 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 135 - best performance: 0.13196003352908717
# Chosen variable 9: v_GarageScore_TSQ - perf: 0.13447765578594706 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 134 - best performance: 0.13196003352908717
# Chosen variable 9: v_GrLivArea_TLOG - perf: 0.13642272655575738 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 133 - best performance: 0.13196003352908717
# Chosen variable 9: v_AllPorchSF_D - perf: 0.13793467174241378 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 132 - best performance: 0.13196003352908717
# Chosen variable 9: v_ExterQual_E - perf: 0.13526130810793424 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 131 - best performance: 0.13196003352908717
# Chosen variable 9: v_BoughtOffPlan_S - perf: 0.13808613333614334 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 130 - best performance: 0.13196003352908717
# Chosen variable 9: v_KitchenQual_TSQ - perf: 0.13528702389639288 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 129 - best performance: 0.13196003352908717
# Chosen variable 9: v_ExterGrade_D - perf: 0.13908436841286972 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 128 - best performance: 0.13196003352908717
# Chosen variable 9: v_SaleCondition_E - perf: 0.13529262054890878 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 127 - best performance: 0.13196003352908717
# Chosen variable 9: v_YrSold - perf: 0.13713866222025045 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 126 - best performance: 0.13196003352908717
# Chosen variable 9: v_BsmtFinSF1 - perf: 0.1365161595570095 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 125 - best performance: 0.13196003352908717
# Chosen variable 9: v_GarageType_E - perf: 0.1342528419833222 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 124 - best performance: 0.13196003352908717
# Chosen variable 9: v_SimplFireplaceQu_S - perf: 0.13687423078930913 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 123 - best performance: 0.13196003352908717
# Chosen variable 9: v_OverallQual_TL3 - perf: 0.1363791143522599 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 122 - best performance: 0.13196003352908717
# Chosen variable 9: v_YearRemodAdd - perf: 0.13735316003217668 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 121 - best performance: 0.13196003352908717
# Chosen variable 9: v_KitchenQual_TL3 - perf: 0.13770138511756266 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 120 - best performance: 0.13196003352908717
# Chosen variable 9: v_GarageCars_TL2 - perf: 0.13538021255257857 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E
# Variables left: 119 - best performance: 0.13196003352908717
# Chosen variable 9: v_SimplFireplaceScore_D - perf: 0.13149771732627885
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D
# Variables left: 140 - best performance: 0.13149771732627885
# Chosen variable 10: v_SimplOverallQual_TLOG - perf: 0.13544515727724618 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D
# Variables left: 139 - best performance: 0.13149771732627885
# Chosen variable 10: v_FullBath - perf: 0.13433527515867166 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D
# Variables left: 138 - best performance: 0.13149771732627885
# Chosen variable 10: v_SimplExterGrade_D - perf: 0.1358450063716849 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D
# Variables left: 137 - best performance: 0.13149771732627885
# Chosen variable 10: v_ExterQual_TSQ - perf: 0.13332426989857032 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D
# Variables left: 136 - best performance: 0.13149771732627885
# Chosen variable 10: v_BsmtExposure_E - perf: 0.13472110444820998 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D
# Variables left: 135 - best performance: 0.13149771732627885
# Chosen variable 10: v_BsmtFinType1_E - perf: 0.13584114940892522 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D
# Variables left: 134 - best performance: 0.13149771732627885
# Chosen variable 10: v_YearBuilt - perf: 0.13065640903157374
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt
# Variables left: 139 - best performance: 0.13065640903157374
# Chosen variable 11: v_BsmtQual_E - perf: 0.13351775382809564 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt
# Variables left: 138 - best performance: 0.13065640903157374
# Chosen variable 11: v_BsmtFullBath - perf: 0.12898453924407194
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath
# Variables left: 138 - best performance: 0.12898453924407194
# Chosen variable 12: v_OverallGrade_D - perf: 0.13350100243577318 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath
# Variables left: 137 - best performance: 0.12898453924407194
# Chosen variable 12: v_MSZoning_E - perf: 0.12867749442072568
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E
# Variables left: 137 - best performance: 0.12867749442072568
# Chosen variable 13: v_MSSubClass - perf: 0.1286049154782053
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass
# Variables left: 136 - best performance: 0.1286049154782053
# Chosen variable 14: v_OverallQual_TLOG - perf: 0.13217562161967056 - not an improvement deleted
# ...
# Variables left: 117 - best performance: 0.11539652399991786
# Chosen variable 27: v_SimplKitchenQual_S - perf: 0.11755614209041686 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 116 - best performance: 0.11539652399991786
# Chosen variable 27: v_Functional_E - perf: 0.11748233333152568 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 115 - best performance: 0.11539652399991786
# Chosen variable 27: v_KitchenAbvGr - perf: 0.12100922041100341 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 114 - best performance: 0.11539652399991786
# Chosen variable 27: v_FireplaceQu_E - perf: 0.11994978909392062 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 113 - best performance: 0.11539652399991786
# Chosen variable 27: v_EnclosedPorch - perf: 0.11784559614274095 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 112 - best performance: 0.11539652399991786
# Chosen variable 27: v_TotalBath_TL2 - perf: 0.12058898150564201 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 111 - best performance: 0.11539652399991786
# Chosen variable 27: v_ExterQual_TSQ - perf: 0.12010218252553789 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 110 - best performance: 0.11539652399991786
# Chosen variable 27: v_Fence_E - perf: 0.12153444007362471 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 109 - best performance: 0.11539652399991786
# Chosen variable 27: v_GarageCars_TL2 - perf: 0.12001334349516718 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 108 - best performance: 0.11539652399991786
# Chosen variable 27: v_BsmtUnfSF - perf: 0.11868865010387586 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 107 - best performance: 0.11539652399991786
# Chosen variable 27: v_OverallQual - perf: 0.11800186567453361 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 106 - best performance: 0.11539652399991786
# Chosen variable 27: v_BsmtFinSF1 - perf: 0.11797197897894679 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 105 - best performance: 0.11539652399991786
# Chosen variable 27: v_AllFlrsSF_TLOG - perf: 0.11904920846754227 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 104 - best performance: 0.11539652399991786
# Chosen variable 27: v_SimplExterCond_S - perf: 0.120654877377913 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 103 - best performance: 0.11539652399991786
# Chosen variable 27: v_SimplGarageScore_D - perf: 0.11735891501880934 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 102 - best performance: 0.11539652399991786
# Chosen variable 27: v_Alley_E - perf: 0.11987515176054415 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 101 - best performance: 0.11539652399991786
# Chosen variable 27: v_GarageQual_E - perf: 0.11975216484197002 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 100 - best performance: 0.11539652399991786
# Chosen variable 27: v_KitchenQual_TL2 - perf: 0.12007387439410876 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 99 - best performance: 0.11539652399991786
# Chosen variable 27: v_CentralAir_E - perf: 0.12177267335505755 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 98 - best performance: 0.11539652399991786
# Chosen variable 27: v_LandContour_E - perf: 0.12232708013111956 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 97 - best performance: 0.11539652399991786
# Chosen variable 27: v_TotalBath_TSQ - perf: 0.11957420219894851 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 96 - best performance: 0.11539652399991786
# Chosen variable 27: v_PoolScore_D - perf: 0.12115381872440113 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 95 - best performance: 0.11539652399991786
# Chosen variable 27: v_LowQualFinSF - perf: 0.12292123600347131 - not an improvement deleted
# Equation: v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E
# Variables left: 94 - best performance: 0.11539652399991786

# %%
best_perf

# %%
form_base = 'v_SalePrice_TLOG ~ v_OverallQual_TSQ + v_AllSF_TSQ + v_Neighborhood_E + v_TotalBath_TLOG + v_SimplOverallGrade_D + v_GarageCars + v_GarageScore_TL3 + v_GarageScore_TLOG + v_MiscFeature_E + v_SimplFireplaceScore_D + v_YearBuilt + v_BsmtFullBath + v_MSZoning_E + v_MSSubClass + v_OverallCond + v_AllFlrsSF_TL2 + v_GarageFinish_E + v_GrLivArea_TLOG + v_FireplaceScore_D + v_KitchenQual_TLOG + v_SaleCondition_E + v_KitchenQual_TSQ + v_SimplOverallQual_TL3 + v_Exterior1st_E + v_GrLivArea_TL3 + v_GarageScore_TL2 + v_Condition1_E'

# %%
#form_base = 'v_SalePrice_TLOG ~ v_AllSF_TSQ + v_OverallQual_TSQ + v_GarageScore_D + v_TotalBath_TLOG + v_SimplOverallCond_S + v_Neighborhood_E + v_FireplaceQu_E + v_YearBuilt + v_FireplaceScore_D + v_Exterior1st_E + v_Condition1_E'
model = smf.ols(formula = form_base, data = df_train)
fitted = model.fit()
print (fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       v_SalePrice_TLOG   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.893
# Method:                 Least Squares   F-statistic:                     451.3
# Date:                Thu, 02 May 2019   Prob (F-statistic):               0.00
# Time:                        13:43:03   Log-Likelihood:                 2130.4
# No. Observations:                1460   AIC:                            -4205.
# Df Residuals:                    1432   BIC:                            -4057.
# Df Model:                          27
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   2.1209      0.292      7.261      0.000       1.548       2.694
# v_OverallQual_TSQ           0.1104      0.013      8.638      0.000       0.085       0.135
# v_AllSF_TSQ                 0.0041      0.000      8.330      0.000       0.003       0.005
# v_Neighborhood_E            0.0045      0.000     11.300      0.000       0.004       0.005
# v_TotalBath_TLOG            0.0293      0.031      0.960      0.337      -0.031       0.089
# v_SimplOverallGrade_D       0.0013      0.003      0.394      0.694      -0.005       0.008
# v_GarageCars                0.0232      0.005      4.903      0.000       0.014       0.032
# v_GarageScore_TL3        1179.1544   5558.645      0.212      0.832   -9724.805    1.21e+04
# v_GarageScore_TLOG        -10.2693     27.599     -0.372      0.710     -64.409      43.870
# v_MiscFeature_E            -0.0030      0.004     -0.773      0.440      -0.011       0.005
# v_SimplFireplaceScore_D     0.0014      0.006      0.219      0.827      -0.011       0.014
# v_YearBuilt                 0.0006      0.000      5.972      0.000       0.000       0.001
# v_BsmtFullBath              0.0268      0.005      5.869      0.000       0.018       0.036
# v_MSZoning_E                0.0106      0.002      4.275      0.000       0.006       0.015
# v_MSSubClass               -0.0002   4.07e-05     -5.088      0.000      -0.000      -0.000
# v_OverallCond               0.0225      0.003      7.977      0.000       0.017       0.028
# v_AllFlrsSF_TL2             0.0351      0.054      0.653      0.514      -0.070       0.141
# v_GarageFinish_E            0.0065      0.002      2.642      0.008       0.002       0.011
# v_GrLivArea_TLOG          -24.8061     56.703     -0.437      0.662    -136.035      86.423
# v_FireplaceScore_D          0.0042      0.003      1.422      0.155      -0.002       0.010
# v_KitchenQual_TLOG         -2.2700      0.551     -4.117      0.000      -3.352      -1.188
# v_SaleCondition_E           0.0110      0.002      6.222      0.000       0.008       0.014
# v_KitchenQual_TSQ           0.9385      0.217      4.324      0.000       0.513       1.364
# v_SimplOverallQual_TL3      0.0001      0.018      0.006      0.995      -0.035       0.035
# v_Exterior1st_E             0.0010      0.001      1.509      0.131      -0.000       0.002
# v_GrLivArea_TL3             8.3241     18.886      0.441      0.659     -28.722      45.371
# v_GarageScore_TL2       -1763.5963   8350.557     -0.211      0.833   -1.81e+04    1.46e+04
# v_Condition1_E              0.0061      0.002      3.992      0.000       0.003       0.009
# ==============================================================================
# Omnibus:                      671.474   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14283.203
# Skew:                          -1.634   Prob(JB):                         0.00
# Kurtosis:                      17.971   Cond. No.                     1.33e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.2e-11. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Please note that since we revert back to the exponential we need a higher precision
# for the coefficients because otherwise this leads to big erros

# therefore let's increase the decimals when we retrieve the coefficients
pd.set_option('display.float_format', lambda x: '%.8f' % x)

mod_coef = fitted.params
chosen_vars = list(mod_coef.index)
chosen_vars.remove('Intercept')
test_firstRaw = df_test[chosen_vars].iloc[0,]
intercept = mod_coef[0]
mod_coef2 = mod_coef.iloc[1:len(mod_coef)]
b = np.array(mod_coef2)
Xf = np.array(test_firstRaw)
b @ Xf # product row by columns or matrix multiplication
mod_coef
# Out:
# Intercept                     2.12090302
# v_OverallQual_TSQ             0.11040766
# v_AllSF_TSQ                   0.00412204
# v_Neighborhood_E              0.00453914
# v_TotalBath_TLOG              0.02930529
# v_SimplOverallGrade_D         0.00125889
# v_GarageCars                  0.02315804
# v_GarageScore_TL3          1179.15440592
# v_GarageScore_TLOG          -10.26927792
# v_MiscFeature_E              -0.00298308
# v_SimplFireplaceScore_D       0.00136431
# v_YearBuilt                   0.00062629
# v_BsmtFullBath                0.02681719
# v_MSZoning_E                  0.01055251
# v_MSSubClass                 -0.00020701
# v_OverallCond                 0.02248436
# v_AllFlrsSF_TL2               0.03508011
# v_GarageFinish_E              0.00652774
# v_GrLivArea_TLOG            -24.80607643
# v_FireplaceScore_D            0.00415404
# v_KitchenQual_TLOG           -2.26998073
# v_SaleCondition_E             0.01095758
# v_KitchenQual_TSQ             0.93852275
# v_SimplOverallQual_TL3        0.00011045
# v_Exterior1st_E               0.00098531
# v_GrLivArea_TL3               8.32409791
# v_GarageScore_TL2         -1763.59631237
# v_Condition1_E                0.00612140
# dtype: float64

# %% [markdown]
# Now I want to apply lasso and ridge regression. I will apply the Ridge to regularise the variables in my best model and the Lasso instead to perform variable selection and see what model I end up with.

# %% [markdown]
# ### Ridge Regression

# %% [markdown]
# http://www.science.smith.edu/~jcrouser/SDS293/labs/lab10-py.html

# %%
from sklearn.preprocessing import scale 
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV

# %%
alphas = 10*np.linspace(10,-2,100)*0.5
ridge = Ridge(normalize = True)
coefs = []

X = df_train[chosen_vars]
yL = df_train['v_SalePrice_TLOG']

for a in alphas:
    ridge.set_params(alpha = a)
    ridge.fit(X, yL)
    coefs.append(ridge.coef_)
    
np.shape(coefs)
# Out:
# (100, 27)

# %%
ax = plt.gca()
ax.plot(alphas, coefs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
# Out:
# Text(0, 0.5, 'weights')

# %%
y = df_train['v_SalePrice']
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.5, 
                                                    random_state=1)
yL_train = np.log10(y_train)
yL_test = np.log10(y_test)

# %%
ridge3 = Ridge(alpha = 10**10, normalize = True)
# Fit a ridge regression on the training data
ridge3.fit(X_train, yL_train)
# Use the model to predict the data - note that we predict the Logged(SalePrice)
pred3L = ridge3.predict(X_test)
# Print coefficients of the logged model
print(pd.Series(ridge3.coef_, index = X.columns))
# calculate the predict price with the exponential
pred3 = np.power(pred3L, 10)
# calculate the RMSLE that is our KPI
print(rmsle(yL_test, pred3))
# Out:
# v_Alley_E                 -0.00000000
# v_LotArea                  0.00000000
# v_YearBuilt                0.00000000
# v_TotalBsmtSF              0.00000000
# v_GarageArea               0.00000000
# v_LowQualFinSF            -0.00000000
# v_GarageScore_TL3          0.00000000
# v_WoodDeckSF               0.00000000
# v_OverallGrade_D           0.00000000
# v_GarageCars_TL3           0.00000000
# v_OpenPorchSF              0.00000000
# v_MoSold                   0.00000000
# v_2ndFlrSF                 0.00000000
# v_ExterQual_E              0.00000000
# v_FullBath                 0.00000000
# v_OverallQual_TLOG         0.00000000
# v_BsmtUnfSF                0.00000000
# v_GarageGrade_D            0.00000000
# v_AllSF_TLOG               0.00000000
# v_AllFlrsSF_TL2            0.00000000
# v_AllSF_D                  0.00000000
# v_SimplOverallQual_TSQ     0.00000000
# v_AllFlrsSF_TSQ            0.00000000
# v_MasVnrType_E             0.00000000
# v_AllFlrsSF_TLOG           0.00000000
# v_Electrical_E             0.00000000
# v_SimplOverallGrade_D      0.00000000
# v_KitchenQual_E            0.00000000
# v_SimplOverallQual_TL3     0.00000000
# v_GrLivArea_TLOG           0.00000000
#                               ...
# v_SimplHeatingQC_S         0.00000000
# v_KitchenScore_D           0.00000000
# v_ScreenPorch              0.00000000
# v_KitchenQual_TL2          0.00000000
# v_BsmtHalfBath            -0.00000000
# v_Functional_E             0.00000000
# v_FireplaceQu_E            0.00000000
# v_GarageQual_E             0.00000000
# v_GarageFinish_E           0.00000000
# v_AllSF_TSQ                0.00000000
# v_SimplFireplaceScore_D    0.00000000
# v_SimplBsmtQual_S          0.00000000
# v_LandContour_E            0.00000000
# v_GrLivArea                0.00000000
# v_AllSF_TL2                0.00000000
# v_YrSold                   0.00000000
# v_ExterCond_E              0.00000000
# v_PavedDrive_E             0.00000000
# v_AllFlrsSF_D              0.00000000
# v_Heating_E                0.00000000
# v_TotalBath_D              0.00000000
# v_GarageCars_TL2           0.00000000
# v_SimplGarageScore_D       0.00000000
# v_KitchenQual_TL3          0.00000000
# v_GarageCars               0.00000000
# v_SimplBsmtCond_S          0.00000000
# v_TotalBath_TL2            0.00000000
# v_1stFlrSF                 0.00000000
# v_BsmtFinType1_E           0.00000000
# v_GarageCars_TLOG          0.00000000
# Length: 150, dtype: float64
# 14.711109718638792

# %% [markdown]
# For some reason in my source the guy fit the regression with $\lambda = 4$

# %%
ridge2 = Ridge(alpha = 4, normalize = True)
ridge2.fit(X_train, yL_train)
pred2L = ridge2.predict(X_test)
pred2 = np.power(pred2L, 10)
print(pd.Series(ridge2.coef_, index = X.columns))
print(rmsle(y_test, pred2))
# Out:
# v_Alley_E                 -0.00067124
# v_LotArea                  0.00000022
# v_YearBuilt                0.00006295
# v_TotalBsmtSF              0.00000701
# v_GarageArea               0.00001055
# v_LowQualFinSF             0.00000073
# v_GarageScore_TL3          0.00036174
# v_WoodDeckSF               0.00001520
# v_OverallGrade_D           0.00039985
# v_GarageCars_TL3           0.00543750
# v_OpenPorchSF              0.00001566
# v_MoSold                   0.00006440
# v_2ndFlrSF                 0.00000128
# v_ExterQual_E              0.00278065
# v_FullBath                 0.00320444
# v_OverallQual_TLOG         0.03543859
# v_BsmtUnfSF               -0.00000080
# v_GarageGrade_D            0.00025279
# v_AllSF_TLOG               0.02530658
# v_AllFlrsSF_TL2            0.00994834
# v_AllSF_D                  0.00000415
# v_SimplOverallQual_TSQ     0.01240126
# v_AllFlrsSF_TSQ            0.00044379
# v_MasVnrType_E             0.00098218
# v_AllFlrsSF_TLOG           0.01991187
# v_Electrical_E             0.00206996
# v_SimplOverallGrade_D      0.00201054
# v_KitchenQual_E            0.00277532
# v_SimplOverallQual_TL3     0.00798130
# v_GrLivArea_TLOG           0.01960332
#                               ...
# v_SimplHeatingQC_S         0.00328102
# v_KitchenScore_D           0.00101891
# v_ScreenPorch              0.00002797
# v_KitchenQual_TL2          0.00855330
# v_BsmtHalfBath             0.00081181
# v_Functional_E             0.00232222
# v_FireplaceQu_E            0.00111034
# v_GarageQual_E             0.00086994
# v_GarageFinish_E           0.00234407
# v_AllSF_TSQ                0.00044830
# v_SimplFireplaceScore_D    0.00215685
# v_SimplBsmtQual_S          0.00640115
# v_LandContour_E            0.00271762
# v_GrLivArea                0.00000513
# v_AllSF_TL2                0.01264647
# v_YrSold                  -0.00002843
# v_ExterCond_E              0.00145557
# v_PavedDrive_E             0.00254157
# v_AllFlrsSF_D              0.00000527
# v_Heating_E                0.00197905
# v_TotalBath_D              0.00320800
# v_GarageCars_TL2           0.00820032
# v_SimplGarageScore_D       0.00000976
# v_KitchenQual_TL3          0.00520684
# v_GarageCars               0.00297158
# v_SimplBsmtCond_S          0.00236620
# v_TotalBath_TL2            0.00960672
# v_1stFlrSF                 0.00000823
# v_BsmtFinType1_E           0.00016418
# v_GarageCars_TLOG          0.01341303
# Length: 150, dtype: float64
# 4.511290757981986

# %% [markdown]
# Now the guy tries to fit the Ridge Regression with $\lambda = 10^{10}$

# %%
ridge3 = Ridge(alpha = 10**10, normalize = True)
ridge3.fit(X_train, yL_train)
pred3L = ridge3.predict(X_test)
pred3 = np.power(pred3L, 10)
print(pd.Series(ridge3.coef_, index = X.columns))
print(rmsle(y_test, pred3))
# Out:
# v_Alley_E                 -0.00000000
# v_LotArea                  0.00000000
# v_YearBuilt                0.00000000
# v_TotalBsmtSF              0.00000000
# v_GarageArea               0.00000000
# v_LowQualFinSF            -0.00000000
# v_GarageScore_TL3          0.00000000
# v_WoodDeckSF               0.00000000
# v_OverallGrade_D           0.00000000
# v_GarageCars_TL3           0.00000000
# v_OpenPorchSF              0.00000000
# v_MoSold                   0.00000000
# v_2ndFlrSF                 0.00000000
# v_ExterQual_E              0.00000000
# v_FullBath                 0.00000000
# v_OverallQual_TLOG         0.00000000
# v_BsmtUnfSF                0.00000000
# v_GarageGrade_D            0.00000000
# v_AllSF_TLOG               0.00000000
# v_AllFlrsSF_TL2            0.00000000
# v_AllSF_D                  0.00000000
# v_SimplOverallQual_TSQ     0.00000000
# v_AllFlrsSF_TSQ            0.00000000
# v_MasVnrType_E             0.00000000
# v_AllFlrsSF_TLOG           0.00000000
# v_Electrical_E             0.00000000
# v_SimplOverallGrade_D      0.00000000
# v_KitchenQual_E            0.00000000
# v_SimplOverallQual_TL3     0.00000000
# v_GrLivArea_TLOG           0.00000000
#                               ...
# v_SimplHeatingQC_S         0.00000000
# v_KitchenScore_D           0.00000000
# v_ScreenPorch              0.00000000
# v_KitchenQual_TL2          0.00000000
# v_BsmtHalfBath            -0.00000000
# v_Functional_E             0.00000000
# v_FireplaceQu_E            0.00000000
# v_GarageQual_E             0.00000000
# v_GarageFinish_E           0.00000000
# v_AllSF_TSQ                0.00000000
# v_SimplFireplaceScore_D    0.00000000
# v_SimplBsmtQual_S          0.00000000
# v_LandContour_E            0.00000000
# v_GrLivArea                0.00000000
# v_AllSF_TL2                0.00000000
# v_YrSold                   0.00000000
# v_ExterCond_E              0.00000000
# v_PavedDrive_E             0.00000000
# v_AllFlrsSF_D              0.00000000
# v_Heating_E                0.00000000
# v_TotalBath_D              0.00000000
# v_GarageCars_TL2           0.00000000
# v_SimplGarageScore_D       0.00000000
# v_KitchenQual_TL3          0.00000000
# v_GarageCars               0.00000000
# v_SimplBsmtCond_S          0.00000000
# v_TotalBath_TL2            0.00000000
# v_1stFlrSF                 0.00000000
# v_BsmtFinType1_E           0.00000000
# v_GarageCars_TLOG          0.00000000
# Length: 150, dtype: float64
# 4.543893909964634

# %% [markdown]
# Now the guy does what I would've expected at the beginning i.e use cross-validation to tune the value of $\alpha$. This has done using `RidgeCV()`. Anyway from the test we did realise that the best $\alpha$ should be greater than 4 but less than $10^{10}$

# %%
alphas = np.linspace(10E-30, 10**10, 1000)
ridgecv = RidgeCV(alphas = alphas, scoring = 'neg_mean_squared_error', 
                  normalize = True)
ridgecv.fit(X_train, yL_train)
ridgecv.alpha_
# Out:
# 10010010.01001001

# %%
ridge4 = Ridge(alpha = ridgecv.alpha_, normalize = True)
ridge4.fit(X_train, yL_train)
pred4L = ridge4.predict(X_test)
pred4 = np.power(pred4L, 10)
rmsle(y_test, pred4)
# Out:
# 4.543893733569923

# %% [markdown]
# Ridge Regression does not really work becuase before we had a RMSLE of 0.11 and on Kaggle the model has a RMSLE of 0.13 and the Ridge found a RMSLE of 4.5 that makes useless to use the technique.

# %%
import copy
new_vars2 = copy.deepcopy(new_vars)
new_vars2.remove('v_SalePrice')
new_vars2.remove('v_SalePrice_TLOG')
len(new_vars2)
# Out:
# 197

# %%
df_test.shape
# Out:
# (1459, 197)

# %%
df_test.columns = new_vars2

# %%
y_Log_predicted = fitted.predict(df_test)
y_predicted = y_Log_predicted.apply(lambda x: 10 ** x)

# %%
df_test.head()
# Out:
#    v_Id  v_MSSubClass v_MSZoning  v_LotFrontage  v_LotArea v_Street  v_Alley  \
# 0  1461            20         RH         80.000      11622     Pave  MISSING
# 1  1462            20         RL         81.000      14267     Pave  MISSING
# 2  1463            60         RL         74.000      13830     Pave  MISSING
# 3  1464            60         RL         78.000       9978     Pave  MISSING
# 4  1465           120         RL         43.000       5005     Pave  MISSING
#
#   v_LotShape v_LandContour v_Utilities         ...         v_TotalBath_TSQ  \
# 0        Reg           Lvl      AllPub         ...                   1.000
# 1        IR1           Lvl      AllPub         ...                   1.225
# 2        IR1           Lvl      AllPub         ...                   1.581
# 3        IR1           Lvl      AllPub         ...                   1.581
# 4        IR1           HLS      AllPub         ...                   1.414
#
#   v_TotalBath_TLOG v_KitchenQual_TL2 v_KitchenQual_TL3 v_KitchenQual_TSQ  \
# 0            0.301             0.699             0.954             1.414
# 1            0.398             1.000             1.447             1.732
# 2            0.544             0.699             0.954             1.414
# 3            0.544             1.000             1.447             1.732
# 4            0.477             1.000             1.447             1.732
#
#   v_KitchenQual_TLOG v_GarageScore_TL2  v_GarageScore_TL3  v_GarageScore_TSQ  \
# 0              0.477             6.681             10.021             46.797
# 1              0.602             5.943              8.914             30.594
# 2              0.477             6.320              9.481             38.026
# 3              0.602             6.298              9.448             37.550
# 4              0.602             6.363              9.544             38.962
#
#    v_GarageScore_TLOG
# 0               3.341
# 1               2.972
# 2               3.160
# 3               3.150
# 4               3.182
#
# [5 rows x 197 columns]

# %%
y_predicted.index = df_test['v_Id']
y_predicted.columns = ['Id', 'SalePrice']
y_predicted.head()
# Out:
# v_Id
# 1461   110404.00554979
# 1462   147671.28424825
# 1463   170918.59887292
# 1464   198045.31027077
# 1465   192627.23318179
# dtype: float64

# %%
import datetime
prefix = datetime.datetime.now().strftime('%Y%m%d %H%M')
y_predicted.to_csv('../15. Out/' + prefix + ' Submission.csv')
print('15. Out/' + prefix + ' Submission.csv WRITTEN')
# Out:
# 15. Out/20190502 0949 Submission.csv WRITTEN
